# %%
# Import necessary libraries
import yfinance as yf

# Use yfinance to extract Tesla stock data
tesla_data = yf.download("TSLA", start="2022-01-01", end="2022-12-31")

# Reset the index
tesla_data.reset_index(inplace=True)

# Save the dataframe to a CSV file (optional)
tesla_data.to_csv("tesla_stock_data.csv", index=False)

# Display the first five rows
print(tesla_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2022-01-03  382.583344  400.356659  378.679993  399.926666  399.926666
# 1 2022-01-04  396.516663  402.666656  374.350006  383.196655  383.196655
# 2 2022-01-05  382.216675  390.113342  360.336670  362.706665  362.706665
# 3 2022-01-06  359.000000  362.666656  340.166656  354.899994  354.899994
# 4 2022-01-07  360.123322  360.309998  336.666656  342.320007  342.320007
#
#       Volume
# 0  103931400
# 1  100248300
# 2   80119800
# 3   90336600
# 4   84164700

# %%
pip install yfinance pandas matplotlib requests beautifulsoup4

# %%
# Import necessary libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

# Function to make a graph
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Closing Price', marker='o')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# Question 1
# Assuming you have the URL for Tesla stock data
tesla_data = yf.download('TSLA', start='2022-01-01', end='2022-12-31')
tesla_data.reset_index(inplace=True)
tesla_data.head().to_csv('tesla_data_head.csv', index=False)

# Question 2
# Assuming you have the URL for Tesla revenue data
tesla_revenue_url = 'your_tesla_revenue_url_here'
tesla_revenue = pd.read_html(requests.get(tesla_revenue_url).text)[-1]
tesla_revenue.tail().to_csv('tesla_revenue_tail.csv', index=False)

# Question 3
# Assuming you have the URL for GME stock data
gme_data = yf.download('GME', start='2022-01-01', end='2022-12-31')
gme_data.reset_index(inplace=True)
gme_data.head().to_csv('gme_data_head.csv', index=False)

# Question 4
# Assuming you have the URL for GME revenue data
gme_revenue_url = 'your_gme_revenue_url_here'
gme_revenue = pd.read_html(requests.get(gme_revenue_url).text)[-1]
gme_revenue.tail().to_csv('gme_revenue_tail.csv', index=False)

# Question 5
make_graph(tesla_data, 'Tesla Stock Data')

# Question 6
make_graph(gme_data, 'GameStop Stock Data')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-4-42f54aee8f5e> in <cell line: 28>()
#      26 # Assuming you have the URL for Tesla revenue data
#      27 tesla_revenue_url = 'your_tesla_revenue_url_here'
# ---> 28 tesla_revenue = pd.read_html(requests.get(tesla_revenue_url).text)[-1]
#      29 tesla_revenue.tail().to_csv('tesla_revenue_tail.csv', index=False)
#      30
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ...

# %%
# Replace 'your_tesla_revenue_url_here' with the actual URL for Tesla revenue data
tesla_revenue_url = 'https://example.com/tesla_revenue_data'

# %%
# Import necessary libraries
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup

# Function to make a graph
def make_graph(data, title):
    plt.figure(figsize=(10, 6))
    plt.plot(data['Date'], data['Close'], label='Closing Price', marker='o')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# Question 1
# Assuming you have the URL for Tesla stock data
tesla_data = yf.download('TSLA', start='2022-01-01', end='2022-12-31')
tesla_data.reset_index(inplace=True)
tesla_data.head().to_csv('tesla_data_head.csv', index=False)

# Sample revenue data (replace this with actual data)
tesla_revenue_data = {'Date': ['2021-01-01', '2021-04-01', '2021-07-01', '2021-10-01'],
                      'Revenue': [100000000, 120000000, 110000000, 130000000]}

# Create DataFrame
tesla_revenue = pd.DataFrame(tesla_revenue_data)

# Display the last five rows
print(tesla_revenue.tail())


# Question 3
# Assuming you have the URL for GME stock data
gme_data = yf.download('GME', start='2022-01-01', end='2022-12-31')
gme_data.reset_index(inplace=True)
gme_data.head().to_csv('gme_data_head.csv', index=False)

# Question 4
# Assuming you have the URL for GME revenue data
# Sample revenue data for GameStop (replace this with actual data)
gme_revenue_data = {'Date': ['2021-01-01', '2021-04-01', '2021-07-01', '2021-10-01'],
                    'Revenue': [50000000, 60000000, 55000000, 70000000]}

# Create DataFrame
gme_revenue = pd.DataFrame(gme_revenue_data)

# Display the last five rows
print(gme_revenue.tail())

# Question 5
make_graph(tesla_data, 'Tesla Stock Data')

# Question 6
make_graph(gme_data, 'GameStop Stock Data')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#          Date    Revenue
# 0  2021-01-01  100000000
# 1  2021-04-01  120000000
# 2  2021-07-01  110000000
# 3  2021-10-01  130000000
# [*********************100%%**********************]  1 of 1 completed
#          Date   Revenue
# 0  2021-01-01  50000000
# 1  2021-04-01  60000000
# 2  2021-07-01  55000000
# 3  2021-10-01  70000000

# %%
# Reset the index and display the first five rows of the tesla_data dataframe
tesla_data.head().to_csv('tesla_data_head.csv', index=False)

# %%
# Display the last five rows of the tesla_revenue dataframe (placeholder response)
print("Tesla Revenue Data: Placeholder Response")
# Out:
# Tesla Revenue Data: Placeholder Response

# %%
# Reset the index and display the first five rows of the gme_data dataframe
gme_data.head().to_csv('gme_data_head.csv', index=False)

# %%
# Display the last five rows of the gme_revenue dataframe (placeholder response)
print("GME Revenue Data: Placeholder Response")
# Out:
# GME Revenue Data: Placeholder Response

# %%
# Use the make_graph function to graph the Tesla Stock Data with a title
make_graph(tesla_data, 'Tesla Stock Data')

# %%
# Use the make_graph function to graph the GameStop Stock Data with a title
make_graph(gme_data, 'GameStop Stock Data')
